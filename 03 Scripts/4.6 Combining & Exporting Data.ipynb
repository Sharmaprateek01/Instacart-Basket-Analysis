# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Importing Data

# %%
df_ords_prods_comb=pd.read_pickle(r'/Users/prateeksharma/Documents/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
path=r'/Users/prateeksharma/Documents/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/prateeksharma/Documents/Instacart Basket Analysis'

# %%
df_ords_prods_comb=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
df_prods=pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'),index_col=0)

# %%
df_ords_prods_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           1   2398795        1             2          3                  7
# 1           1   2398795        1             2          3                  7
# 2           1   2398795        1             2          3                  7
# 3           1   2398795        1             2          3                  7
# 4           1   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    15.0         196                  1          1   both
# 1                    15.0       10258                  2          0   both
# 2                    15.0       12427                  3          1   both
# 3                    15.0       13176                  4          0   both
# 4                    15.0       26088                  5          1   both

# %%
#Dropping unnamed col
df_ords_prods_comb.columns = df_ords_prods_comb.columns.str.strip()
df_ords_prods_comb = df_ords_prods_comb.drop(columns=['Unnamed: 0'])

# %%
#Checking shape of df_ords_prods_comb
df_ords_prods_comb.shape
# Out:
# (30356421, 10)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
##Checking shape of df_prods
df_prods.shape
# Out:
# (49672, 5)

# %%
#Merge df_prods and df_ords_prods_comb on 'product_id'
df_merged=df_prods.merge(df_ords_prods_comb, on ='product_id', how='inner')

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3   1813452      764             3          4                 17
# 4   1701441      777            16          1                  7
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# ...

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 30328758       49688      Fresh Foaming Cleanser        73             11
# 30328759       49688      Fresh Foaming Cleanser        73             11
# 30328760       49688      Fresh Foaming Cleanser        73             11
# 30328761       49688      Fresh Foaming Cleanser        73             11
# 30328762       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  order_dow  \
# ...

# %%
#Merge flag
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          30328763
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
